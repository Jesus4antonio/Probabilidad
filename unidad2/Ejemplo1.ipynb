# %% [markdown]
# <a href="https://colab.research.google.com/github/Jesus4antonio/Probabilidad/blob/main/unidad2/Ejemplo1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PROBABILIDAD Y ESTADISTICA
#
# ## UNIDAD 2
#
# ### FACILITADOR: Jose Gabriel Rodruguez
#
# ### Alumno: Jesus Antonio Sanchez Aguilar
#
# ## **Ejemplo No.1**

# %%
import math as mt #  Para utilizar facctorial
from itertools import combinations
from itertools import combinations_with_replacement
import numpy as np

# %%
nombres = ["Oscar", "Paco" , "Paty", "Laura", "Rubén","Luis","Lucy","Alberto","Juan", "Danny"]
n = len(nombres)
r = 2 # ¿Cómo agrupar?

Cn = mt.factorial(n) / (mt.factorial(r) * mt.factorial(n-r))
print("Exsiten", Cn , "posibles combinacioners sin repetición del total de ", n ," nombres", "en grupos de",r, "en",r)
print("Aqui las combinaciones ")
combinaciones_nombres = list (combinations (nombres,r))

for combinacion in combinaciones_nombres:
    print(combinacion)
# Out:
# Exsiten 45.0 posibles combinacioners sin repetición del total de  10  nombres en grupos de 2 en 2
# Aqui las combinaciones
# ('Oscar', 'Paco')
# ('Oscar', 'Paty')
# ('Oscar', 'Laura')
# ('Oscar', 'Rubén')
# ('Oscar', 'Luis')
# ('Oscar', 'Lucy')
# ('Oscar', 'Alberto')
# ('Oscar', 'Juan')
# ('Oscar', 'Danny')
# ('Paco', 'Paty')
# ('Paco', 'Laura')
# ('Paco', 'Rubén')
# ('Paco', 'Luis')
# ('Paco', 'Lucy')
# ('Paco', 'Alberto')
# ('Paco', 'Juan')
# ('Paco', 'Danny')
# ('Paty', 'Laura')
# ('Paty', 'Rubén')
# ('Paty', 'Luis')
# ('Paty', 'Lucy')
# ('Paty', 'Alberto')
# ('Paty', 'Juan')
# ('Paty', 'Danny')
# ('Laura', 'Rubén')
# ('Laura', 'Luis')
# ('Laura', 'Lucy')
# ('Laura', 'Alberto')
# ('Laura', 'Juan')
# ('Laura', 'Danny')
# ('Rubén', 'Luis')
# ('Rubén', 'Lucy')
# ('Rubén', 'Alberto')
# ('Rubén', 'Juan')
# ('Rubén', 'Danny')
# ('Luis', 'Lucy')
# ('Luis', 'Alberto')
# ('Luis', 'Juan')
# ('Luis', 'Danny')
# ('Lucy', 'Alberto')
# ('Lucy', 'Juan')
# ('Lucy', 'Danny')
# ('Alberto', 'Juan')
# ...
