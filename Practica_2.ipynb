# %% [markdown]
# <a href="https://colab.research.google.com/github/Jesus4antonio/Probabilidad/blob/main/Practica_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PROBABILIDAD Y ESTADISTICA
#
# ## UNIDAD 1
#
# ### FACILITADOR: Jose Gabriel Rodruguez
#
# ### Alumno: Jesus Antonio Sanchez Aguilar
#
# ## **Programa 2: Maximo,Minimo y Disperción de Datos**

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
fabrica1 = []
for i in range(100):
  numero_aleatorio = round(random.uniform(50, 100), 2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [60.03, 57.81, 56.85, 92.54, 51.73, 65.18, 59.46, 61.82, 93.63, 88.61, 82.11, 61.99, 61.18, 81.34, 97.68, 89.42, 85.05, 88.87, 64.74, 76.58, 79.64, 58.37, 85.32, 68.69, 63.56, 76.12, 81.04, 87.35, 72.69, 97.23, 90.91, 56.32, 94.21, 70.4, 81.25, 68.62, 63.93, 82.17, 95.42, 66.27, 54.24, 70.0, 97.95, 77.6, 77.64, 99.27, 71.74, 53.64, 56.01, 75.1, 68.23, 66.24, 60.84, 54.04, 92.43, 61.69, 76.19, 50.8, 51.7, 69.74, 57.61, 72.14, 89.41, 85.66, 75.36, 95.34, 70.55, 70.24, 65.17, 75.85, 59.45, 84.93, 94.39, 79.09, 80.55, 91.6, 71.98, 77.22, 92.1, 69.95, 90.95, 86.09, 65.73, 78.39, 50.06, 54.88, 73.13, 59.33, 96.02, 99.34, 81.82, 66.5, 54.49, 53.52, 63.12, 82.76, 77.68, 86.43, 82.95, 91.21]

# %%
fabrica2 = []
for i in range(100):
  numero_aleatorio = round(random.uniform(50, 100), 2)
  fabrica2.append(numero_aleatorio)
print(fabrica2)
# Out:
# [59.61, 88.2, 58.21, 57.94, 69.07, 72.8, 60.2, 93.19, 96.18, 56.0, 64.56, 51.02, 89.36, 86.5, 60.26, 60.65, 65.87, 50.2, 98.4, 79.94, 79.71, 50.65, 98.26, 50.76, 92.16, 72.23, 52.2, 96.83, 88.97, 60.63, 83.77, 60.3, 86.49, 99.03, 71.3, 80.03, 51.42, 90.25, 61.63, 73.1, 76.84, 76.71, 95.53, 56.11, 50.65, 81.2, 58.93, 66.71, 68.58, 88.52, 90.86, 87.87, 62.28, 60.47, 52.88, 88.49, 74.88, 85.92, 87.66, 65.45, 97.29, 96.37, 75.28, 56.13, 61.28, 83.58, 97.38, 50.64, 69.57, 99.18, 64.52, 71.72, 97.81, 81.28, 97.02, 84.58, 74.85, 83.47, 73.68, 57.15, 52.26, 60.86, 63.1, 58.48, 64.09, 90.17, 72.78, 65.86, 95.57, 68.58, 55.55, 91.87, 53.25, 80.81, 96.28, 75.21, 53.17, 92.06, 68.26, 62.21]

# %%
maximo1 = max(fabrica1)
minimo1 = min(fabrica1)
rango1 = maximo1 - minimo1
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)
desviacion_estandar_fabrica1 = stdev(fabrica1)

print("Estadisticas descriptiva de la Fabrica 1 \n", "Media =",media1,
      "\n Mediana =", mediana1,"\n Moda =", moda1, "\n Maximo =",maximo1,
      "\n Minimo =", minimo1,"\n Rango=", rango1)
print(desviacion_estandar_fabrica1)
# Out:
# Estadisticas descriptiva de la Fabrica 1
#  Media = 74.5421
#  Mediana = 75.22999999999999
#  Moda = 60.03
#  Maximo = 99.34
#  Minimo = 50.06
#  Rango= 49.28
# 13.89775625339529

# %%
maximo2 = max(fabrica2)
minimo2 = min(fabrica2)
rango2 = maximo2 - minimo2
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)
desviacion_estandar_fabrica2 = stdev(fabrica2)

print("Estadisticas descriptiva de la Fabrica 1 \n", "Media =",media2,
      "\n Mediana =", mediana2,"\n Moda =", moda2, "\n Maximo =",maximo2,
      "\n Minimo =", minimo2,"\n Rango=", rango2)
print(desviacion_estandar_fabrica2)
# Out:
# Estadisticas descriptiva de la Fabrica 1
#  Media = 73.8762
#  Mediana = 72.78999999999999
#  Moda = 50.65
#  Maximo = 99.18
#  Minimo = 50.2
#  Rango= 48.980000000000004
# 15.501867582502907

# %%
plt.figure(figsize=(8,6))
plt.hist(fabrica1, bins=10, alpha=0.2, color='b', edgecolor='black')
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label=f'Media={media1:.2f}')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana1:.2f}')
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label=f'Moda={moda1:.2f}')
plt.axvline(media1 - desviacion_estandar_fabrica1, color='black', linestyle='dashed', linewidth=2, label=f'Desviacion Estandar={desviacion_estandar_fabrica1:.2f}')
plt.axvline(media1 + desviacion_estandar_fabrica1, color='black', linestyle='dashed', linewidth=2)

plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title('Producción diaria de la fabrica 1')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.hist(fabrica2, bins=10, alpha=0.2, color='b', edgecolor='black')
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label=f'Media={media2:.2f}')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana2:.2f}')
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label=f'Moda={moda2:.2f}')
plt.axvline(media2 - desviacion_estandar_fabrica2, color='black', linestyle='dashed', linewidth=2, label=f'Desviacion Estandar={desviacion_estandar_fabrica2:.2f}')
plt.axvline(media2 + desviacion_estandar_fabrica2, color='black', linestyle='dashed', linewidth=2)

plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title('Producción diaria de la fabrica 2')
plt.legend()
plt.show()

# %%
import seaborn as sns
# La densidad gráfica es uan forma de visualizar la distribución de datos en un intervalo o periodo de tiempo continuo.
# Se basa en un histograma  que usa el suavizado de kernel para trazar valores, lo qeu permite optener distribuciones mas suaves al reduci el ruido.
# Una curva de densidad muestra una ubicación de la media y la mediana en una distribución.

sns.histplot(fabrica1, kde=True, kde_kws = {'bw_adjust': 0.5}, bins = 10)
# Out:
# <Axes: ylabel='Count'>
