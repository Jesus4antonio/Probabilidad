# %% [markdown]
# <a href="https://colab.research.google.com/github/Jesus4antonio/Probabilidad/blob/main/Practica_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PROBABILIDAD Y ESTADISTICA
#
# ## UNIDAD 1
#
# ### FACILITADOR: Jose Gabriel Rodruguez
#
# ### Alumno: Jesus Antonio Sanchez Aguilar
#
# ## **Programa 1: Estadistica basica e Histrogramas**

# %%
from statistics import*

# %%
# Lista de calificaciones del grupo a de probabilidad  y estadistica
grupoa = [70, 65,90,100,95,45,88,73,20,100,96]
print(grupoa)
type(grupoa)
promedio = sum(grupoa) / len(grupoa)
# Out:
# [70, 65, 90, 100, 95, 45, 88, 73, 20, 100, 96]

# %%
# la funcion type nos devuelve el tipo de dato de la variable
type(grupoa)
# Out:
# list

# %%
# Sacar la media de las calificaciones  con una formula
promedio = sum(grupoa) / len(grupoa)

# %%
# Utilizar la funcion mean que esta en la libreria statistics para sacar
# Promedio:
promedio2 = mean(grupoa)
print(promedio2)
# Out:
# 76.54545454545455

# %%
# Determinar el valor de la mediana con la funcion median
# Cambiamos el nombre de la variable para no sobrescribir la funcion median
mediana_resultado = median(grupoa)
print(mediana_resultado)
# Out:
# 88

# %%
# Determinar el valor de la moda con la funcion mode
moda = mode(grupoa)
print(moda)
# Out:
# 100

# %%
# En caso de que exista mas de una moda de exista mas de una moda, se puede emplear la funcion multimode para sac
# Multiples modas que pueden llegar a existir
moda2 = multimode (grupoa)
print(moda2)
# Out:
# [100]

# %%
tiempos100mts = [15.10,17.20,14.69,13.27,22.15,18.71,19.15,20.65,15.10,17.20]
print(tiempos100mts)
# Out:
# [15.1, 17.2, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.1, 17.2]

# %%
from statistics import median, mode

print("El tiempo promedio de los corredores es=>", mean(tiempos100mts))
print("La media promedio de los corredores es=>", median(tiempos100mts))
print("La moda promedio de los corredores es=>", mode(tiempos100mts))
# Out:
# El tiempo promedio de los corredores es=> 17.322
# La media promedio de los corredores es=> 17.2
# La moda promedio de los corredores es=> 15.1

# %%
import random

# %%
fabrica1 =[]
for i in range(100):
    numero_aleatorio = round(random.uniform(50,100),2)
    fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [67.74, 89.6, 79.37, 93.25, 58.12, 72.53, 77.59, 76.81, 91.52, 98.59, 58.95, 68.49, 85.63, 83.27, 80.34, 88.07, 72.17, 90.63, 90.67, 87.07, 71.41, 52.53, 85.68, 64.12, 63.13, 61.92, 99.97, 60.94, 77.58, 53.93, 57.59, 85.42, 83.39, 87.57, 95.23, 72.31, 74.64, 53.5, 92.89, 84.81, 87.28, 81.47, 68.77, 59.7, 54.49, 66.89, 65.6, 91.38, 75.22, 73.81, 59.86, 98.34, 73.14, 99.86, 73.59, 50.96, 76.44, 70.97, 90.17, 99.71, 91.65, 76.62, 58.71, 59.5, 58.38, 98.96, 73.72, 73.38, 53.1, 83.47, 96.29, 59.22, 76.47, 82.54, 88.07, 80.86, 82.83, 94.21, 83.37, 54.0, 94.53, 94.89, 66.16, 87.27, 53.1, 75.25, 64.61, 83.53, 69.05, 62.62, 90.87, 73.18, 72.71, 55.99, 59.97, 87.36, 58.41, 83.03, 78.74, 84.25]

# %%
fabrica2 =[]
for i in range(100):
    numero_aleatorio = round(random.uniform(70,100),2)
    fabrica2.append(numero_aleatorio)
print(fabrica2)
# Out:
# [70.96, 71.57, 99.85, 82.38, 87.7, 81.44, 77.77, 83.72, 76.25, 80.29, 91.99, 84.78, 93.37, 78.54, 90.93, 93.82, 80.25, 81.0, 88.57, 76.87, 97.22, 77.7, 90.56, 87.06, 95.16, 82.08, 72.56, 95.41, 74.66, 73.53, 76.95, 90.11, 85.79, 90.61, 72.39, 70.54, 84.13, 77.05, 80.89, 84.52, 92.51, 92.21, 74.46, 83.35, 95.15, 96.61, 89.08, 82.55, 92.17, 90.08, 91.15, 81.86, 77.04, 80.83, 84.55, 89.07, 92.62, 71.31, 96.48, 83.64, 73.85, 93.59, 96.71, 98.59, 89.88, 95.94, 74.4, 73.4, 98.15, 82.15, 89.9, 94.75, 77.88, 76.43, 92.42, 86.94, 87.28, 92.26, 90.66, 70.0, 88.63, 86.65, 92.72, 83.61, 73.83, 84.93, 79.17, 92.47, 79.0, 92.25, 92.91, 82.31, 80.18, 89.77, 86.82, 87.11, 91.76, 79.73, 77.01, 94.81]

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(fabrica1)
plt.title("Producción diaria de la fabrica 1")
# Out:
# Text(0.5, 1.0, 'Producción diaria de la fabrica 1')

# %%
plt.hist(fabrica2)
plt.title("Producción diaria de la fabrica 2")
# Out:
# Text(0.5, 1.0, 'Producción diaria de la fabrica 2')

# %%
media1 = mean(fabrica1)
mediana = median(fabrica1)
moda = mode(fabrica1)

print("Valores de l afabrica 1")
print("La media es=>", media1)
print("La mediana es=>", mediana)
print("La moda  es=>", moda)
# Out:
# Valores de l afabrica 1
# La media es=> 76.2749
# La mediana es=> 76.545
# La moda  es=> 88.07

# %%
media2 = mean(fabrica2)
mediana = median(fabrica2)
moda = mode(fabrica2)

print("Valores de l afabrica 2")
print("La media es=>", media2)
print("La mediana es=>", mediana)
print("La moda  es=>", moda)
# Out:
# Valores de l afabrica 2
# La media es=> 85.1854
# La mediana es=> 85.36000000000001
# La moda  es=> 70.96

# %%
fig,(ax1,ax2) = plt.subplots(nrows=1,ncols=2,figsize=(10,5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()
