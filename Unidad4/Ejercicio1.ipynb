# %% [markdown]
# <a href="https://colab.research.google.com/github/Jesus4antonio/Probabilidad/blob/main/Unidad4/Ejercicio1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
# Generar datos para las distribución normal

media = 70 #Media
desv_std = 4 #Desviación estándar
num_datos = 500

# %%
# generamos los datos de manera aleatoria y lon ponemos en una lista (array)
datos = np.random.normal(media, desv_std, num_datos)
datos [0:50] #Mostrar los primeros 50
# Out:
# array([68.74309291, 73.11601528, 74.10949517, 68.89093551, 70.97230158,
#        71.23799159, 69.60122978, 66.15962436, 62.03739127, 77.3572304 ,
#        72.56907368, 71.19385986, 65.45011975, 72.19959603, 70.46915466,
#        72.4169952 , 67.77607725, 73.1318532 , 76.75148773, 66.67228963,
#        69.66385074, 71.84074737, 74.01176624, 77.90232361, 70.20394505,
#        63.6062431 , 68.206854  , 69.74477398, 71.98576431, 65.35498148,
#        62.96613616, 72.28437802, 77.52776756, 73.60234952, 71.85753688,
#        69.75795371, 63.98323083, 69.14008327, 72.90085951, 67.90791902,
#        66.92772248, 68.49857018, 65.84262385, 68.82780455, 73.57377149,
#        67.21679599, 62.79690601, 80.72987795, 71.16967593, 71.54294113])

# %%
# # Crear un rango de valores para crear una densidad
x = np.linspace(media - 3 * desv_std, media + 3 * desv_std, num_datos)

  # Calcular la PDF de la distribucion normal
pdf = 1 / (desv_std * np.sqrt(2 * np.pi)) * np
print ("Imprimir los primeros 50 valores de x", x[0:50 ])
